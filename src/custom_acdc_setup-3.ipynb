# %% [markdown]
# ### Custom ACDC Setup
#
# This is a simple notebook for Automated Circuit DisCovery (ACDC) (https://arxiv.org/pdf/2304.14997.pdf) in custom settings. It follows the basic steps proposed in the accompanied paper. The current idea is to copy this notebook for each behavior under investigation. In the future, it might make sense to build a more modular solution to this, to make existing observations easier to reproduce by anyone.
#
# To serve as an example, this notebook implements ACDC for 'greater_than' in a GPT2-small.

# %%
try:
    import google.colab

    IN_COLAB = True
    print("Running as a Colab notebook")

    import subprocess  # to install graphviz dependencies

    command = ["apt-get", "install", "graphviz-dev"]
    subprocess.run(command, check=True)

    import os  # make images folder

    os.mkdir("ims/")

    from IPython import get_ipython

    ipython = get_ipython()

    ipython.run_line_magic(  # install ACDC
        "pip",
        "install git+https://github.com/ArthurConmy/Automatic-Circuit-Discovery.git@d89f7fa9cbd095202f3940c889cb7c6bf5a9b516",
    )

except Exception as e:
    IN_COLAB = False
    print("Running outside of colab")

    import numpy  # crucial to not get cursed error
    import plotly

    plotly.io.renderers.default = "colab"  # added by Arthur so running as a .py notebook with #%% generates .ipynb notebooks that display in colab
    # disable this option when developing rather than generating notebook outputs

    import os  # make images folder

    if not os.path.exists("ims/"):
        os.mkdir("ims/")

    from IPython import get_ipython

    ipython = get_ipython()
    if ipython is not None:
        print("Running as a notebook")
        ipython.run_line_magic("load_ext", "autoreload")  # type: ignore
        ipython.run_line_magic("autoreload", "2")  # type: ignore
    else:
        print("Running as a script")
# Out:
# Running outside of colab
# Running as a notebook

# %%
import os
import torch

# some GPU setup
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# #### Step 1: Select a Behavior, Dataset, and Metric

# %% [markdown]
# ##### Model

# %%
from transformer_lens import HookedTransformer

reference_gpt2 = HookedTransformer.from_pretrained(
    "gpt2-small", fold_ln=False, center_unembed=False, center_writing_weights=False
)
# Out:
# Loaded pretrained model gpt2-small into HookedTransformer

# %% [markdown]
# ##### Dataset

# %%
from Automatic_Circuit_Discovery.acdc.greaterthan.utils import get_year_data

# generate textual input examples and tokenize them
tokenized_inputs, inputs = get_year_data(n_examples, model)
print(f"Input Example: '{inputs[0]} \nTokenized as: {tokenized_inputs[0]}'")

# generate corrupted inputs
corrupted_tokenized_inputs = tokenized_inputs.clone()
corrupted_tokenized_inputs[:, 7] = 486  # replace with 01

# select N examples
tokenized_inputs = tokenized_inputs[:n_examples]
corrupted_tokenized_inputs = corrupted_tokenized_inputs[:n_examples]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /root/SPAR/src/custom_acdc_setup-3.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bssh4.vast.ai/root/SPAR/src/custom_acdc_setup-3.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from ..Automatic_Circuit_Discovery.acdc.greaterthan.utils import get_year_data
#       <a href='vscode-notebook-cell://ssh-remote%2Bssh4.vast.ai/root/SPAR/src/custom_acdc_setup-3.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # generate textual input examples and tokenize them
#       <a href='vscode-notebook-cell://ssh-remote%2Bssh4.vast.ai/root/SPAR/src/custom_acdc_setup-3.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> tokenized_inputs, inputs = get_year_data(n_examples, model)
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# ##### Metric

# %%
METRIC = "greater_than"

# %%
import torch.nn.functional as F
from functools import partial

from acdc.acdc_utils import kl_divergence, negative_log_probs
from acdc.greaterthan.utils import greaterthan_metric


with torch.no_grad():
    logits = model(tokenized_inputs)[:, -1, :]
    logprobs = F.log_softmax(logits, dim=-1)

if METRIC == "kl_divergence":
    validation_metric = partial(
        kl_divergence,
        base_model_logprobs=logprobs,
        mask_repeat_candidates=None,
        last_seq_element_only=False,
    )

elif METRIC == "greater_than":
    validation_metric = partial(greaterthan_metric, tokens=tokenized_inputs.cpu())

else:
    raise ValueError(f"Unknown Metric {METRIC}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /root/SPAR/Automatic-Circuit-Discovery/custom_acdc_setup-3.ipynb Cell 11 line 5
#       <a href='vscode-notebook-cell://ssh-remote%2Bssh4.vast.ai/root/SPAR/Automatic-Circuit-Discovery/custom_acdc_setup-3.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from functools import partial
#       <a href='vscode-notebook-cell://ssh-remote%2Bssh4.vast.ai/root/SPAR/Automatic-Circuit-Discovery/custom_acdc_setup-3.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> from acdc.acdc_utils import kl_divergence, negative_log_probs
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bssh4.vast.ai/root/SPAR/Automatic-Circuit-Discovery/custom_acdc_setup-3.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> from acdc.greaterthan.utils import greaterthan_metric
#       <a href='vscode-notebook-cell://ssh-remote%2Bssh4.vast.ai/root/SPAR/Automatic-Circuit-Discovery/custom_acdc_setup-3.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> with torch.no_grad():
#       <a href='vscode-notebook-cell://ssh-remote%2Bssh4.vast.ai/root/SPAR/Automatic-Circuit-Discovery/custom_acdc_setup-3.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     logits = model(tokenized_inputs)[:, -1, :]
#
# File ~/SPAR/Automatic-Circuit-Discovery/acdc/greaterthan/utils.py:15
#      13 from acdc.acdc_utils import kl_divergence
#      14 import torch
# ---> 15 from acdc.ioi.ioi_dataset import IOIDataset  # NOTE: we now import this LOCALLY so it is deterministic
#      16 from tqdm import tqdm
#      17 import wandb
#
# File ~/SPAR/Automatic-Circuit-Discovery/acdc/ioi/ioi_dataset.py:19
#      17 import random
#      18 import re
# ---> 19 import matplotlib.pyplot as plt
#      20 import copy
#      22 NAMES = [
#      23     "Michael",
#      24     "Christopher",
#    (...)
#     121     "Samuel",
#     122 ]
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# #### Step 2: Divide the Neural Network into a Graph of Smaller Units

# %%
import time
from dataclasses import dataclass, asdict

from acdc.TLACDCExperiment import TLACDCExperiment


@dataclass
class ACDCExperimentArguments:
    threshold: float = 0.71
    zero_ablation: bool = True
    verbose: bool = True
    indices_mode: str = "reverse"
    names_mode: str = "normal"
    corrupted_cache_cpu = False
    hook_verbose: bool = False
    online_cache_cpu: bool = False
    add_sender_hooks: bool = True
    add_receiver_hooks: bool = False
    remove_redundant: bool = False
    show_full_index: bool = str(TASK).startswith("tracr")
    use_pos_embed: bool = str(TASK).startswith("tracr")

    # weights and biases
    using_wandb: bool = False
    wandb_project_name: str = "hackathon"
    wandb_run_name: str = f"{int(time.time())}"
    wandb_entity_name: str = "entity"
    wandb_group_name: str = "group"
    wandb_notes: str = ""
    wandb_dir: str = "wandb"
    wandb_mode: str = "online"


args = asdict(ACDCExperimentArguments())

model.reset_hooks()
exp = TLACDCExperiment(
    model=model,
    ds=tokenized_inputs,
    ref_ds=corrupted_tokenized_inputs,
    metric=validation_metric,
    **args,
)
# Out:
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# /home/jbrinkmann/Documents/GitHub/miniconda3/envs/mechint/lib/python3.11/site-packages/acdc/TLACDCExperiment.py:130: UserWarning: We shall overwrite the ref_ds with zeros.
#   warnings.warn("We shall overwrite the ref_ds with zeros.")
# WARNING:root:cache_all is deprecated and will eventually be removed, use add_caching_hooks or run_with_cache
# dict_keys(['blocks.11.hook_resid_post', 'blocks.11.hook_mlp_out', 'blocks.11.hook_mlp_in', 'blocks.11.attn.hook_result', 'blocks.11.attn.hook_q', 'blocks.11.hook_q_input', 'blocks.11.attn.hook_k', 'blocks.11.hook_k_input', 'blocks.11.attn.hook_v', 'blocks.11.hook_v_input', 'blocks.10.hook_mlp_out', 'blocks.10.hook_mlp_in', 'blocks.10.attn.hook_result', 'blocks.10.attn.hook_q', 'blocks.10.hook_q_input', 'blocks.10.attn.hook_k', 'blocks.10.hook_k_input', 'blocks.10.attn.hook_v', 'blocks.10.hook_v_input', 'bl
# blocks.11.hook_resid_mid
# blocks.11.hook_attn_out
# blocks.11.attn.hook_result
# blocks.11.attn.hook_z
# blocks.11.attn.hook_pattern
# blocks.11.attn.hook_attn_scores
# blocks.11.attn.hook_v
# blocks.11.attn.hook_k
# blocks.11.attn.hook_q
# blocks.11.ln1.hook_normalized
# blocks.11.ln1.hook_scale
# blocks.11.hook_v_input
# blocks.11.hook_k_input
# blocks.11.hook_q_input
# blocks.11.hook_resid_pre
# blocks.10.hook_resid_post
# blocks.10.hook_mlp_out
# blocks.10.mlp.hook_post
# blocks.10.mlp.hook_pre
# blocks.10.ln2.hook_normalized
# blocks.10.ln2.hook_scale
# blocks.10.hook_mlp_in
# blocks.10.hook_resid_mid
# blocks.10.hook_attn_out
# blocks.10.attn.hook_result
# blocks.10.attn.hook_z
# blocks.10.attn.hook_pattern
# blocks.10.attn.hook_attn_scores
# blocks.10.attn.hook_v
# blocks.10.attn.hook_k
# blocks.10.attn.hook_q
# blocks.10.ln1.hook_normalized
# blocks.10.ln1.hook_scale
# blocks.10.hook_v_input
# blocks.10.hook_k_input
# blocks.10.hook_q_input
# blocks.10.hook_resid_pre
# blocks.9.hook_resid_post
# blocks.9.hook_mlp_out
# blocks.9.mlp.hook_post
# blocks.9.mlp.hook_pre
# blocks.9.ln2.hook_normalized
# blocks.9.ln2.hook_scale
# blocks.9.hook_mlp_in
# blocks.9.hook_resid_mid
# blocks.9.hook_attn_out
# blocks.9.attn.hook_result
# blocks.9.attn.hook_z
# blocks.9.attn.hook_pattern
# blocks.9.attn.hook_attn_scores
# blocks.9.attn.hook_v
# blocks.9.attn.hook_k
# blocks.9.attn.hook_q
# blocks.9.ln1.hook_normalized
# blocks.9.ln1.hook_scale
# blocks.9.hook_v_input
# blocks.9.hook_k_input
# blocks.9.hook_q_input
# blocks.9.hook_resid_pre
# blocks.8.hook_resid_post
# blocks.8.hook_mlp_out
# blocks.8.mlp.hook_post
# blocks.8.mlp.hook_pre
# blocks.8.ln2.hook_normalized
# blocks.8.ln2.hook_scale
# blocks.8.hook_mlp_in
# blocks.8.hook_resid_mid
# blocks.8.hook_attn_out
# blocks.8.attn.hook_result
# blocks.8.attn.hook_z
# blocks.8.attn.hook_pattern
# blocks.8.attn.hook_attn_scores
# blocks.8.attn.hook_v
# blocks.8.attn.hook_k
# blocks.8.attn.hook_q
# blocks.8.ln1.hook_normalized
# blocks.8.ln1.hook_scale
# blocks.8.hook_v_input
# blocks.8.hook_k_input
# blocks.8.hook_q_input
# blocks.8.hook_resid_pre
# blocks.7.hook_resid_post
# blocks.7.hook_mlp_out
# blocks.7.mlp.hook_post
# blocks.7.mlp.hook_pre
# blocks.7.ln2.hook_normalized
# blocks.7.ln2.hook_scale
# blocks.7.hook_mlp_in
# blocks.7.hook_resid_mid
# blocks.7.hook_attn_out
# blocks.7.attn.hook_result
# blocks.7.attn.hook_z
# blocks.7.attn.hook_pattern
# blocks.7.attn.hook_attn_scores
# blocks.7.attn.hook_v
# blocks.7.attn.hook_k
# blocks.7.attn.hook_q
# blocks.7.ln1.hook_normalized
# blocks.7.ln1.hook_scale
# blocks.7.hook_v_input
# blocks.7.hook_k_input
# blocks.7.hook_q_input
# blocks.7.hook_resid_pre
# blocks.6.hook_resid_post
# blocks.6.hook_mlp_out
# blocks.6.mlp.hook_post
# blocks.6.mlp.hook_pre
# blocks.6.ln2.hook_normalized
# blocks.6.ln2.hook_scale
# blocks.6.hook_mlp_in
# blocks.6.hook_resid_mid
# blocks.6.hook_attn_out
# blocks.6.attn.hook_result
# blocks.6.attn.hook_z
# blocks.6.attn.hook_pattern
# blocks.6.attn.hook_attn_scores
# blocks.6.attn.hook_v
# blocks.6.attn.hook_k
# blocks.6.attn.hook_q
# blocks.6.ln1.hook_normalized
# blocks.6.ln1.hook_scale
# blocks.6.hook_v_input
# blocks.6.hook_k_input
# blocks.6.hook_q_input
# blocks.6.hook_resid_pre
# blocks.5.hook_resid_post
# blocks.5.hook_mlp_out
# blocks.5.mlp.hook_post
# blocks.5.mlp.hook_pre
# blocks.5.ln2.hook_normalized
# blocks.5.ln2.hook_scale
# blocks.5.hook_mlp_in
# blocks.5.hook_resid_mid
# blocks.5.hook_attn_out
# blocks.5.attn.hook_result
# blocks.5.attn.hook_z
# blocks.5.attn.hook_pattern
# blocks.5.attn.hook_attn_scores
# blocks.5.attn.hook_v
# blocks.5.attn.hook_k
# blocks.5.attn.hook_q
# blocks.5.ln1.hook_normalized
# blocks.5.ln1.hook_scale
# blocks.5.hook_v_input
# blocks.5.hook_k_input
# blocks.5.hook_q_input
# blocks.5.hook_resid_pre
# blocks.4.hook_resid_post
# blocks.4.hook_mlp_out
# blocks.4.mlp.hook_post
# blocks.4.mlp.hook_pre
# blocks.4.ln2.hook_normalized
# blocks.4.ln2.hook_scale
# blocks.4.hook_mlp_in
# blocks.4.hook_resid_mid
# blocks.4.hook_attn_out
# blocks.4.attn.hook_result
# blocks.4.attn.hook_z
# blocks.4.attn.hook_pattern
# blocks.4.attn.hook_attn_scores
# blocks.4.attn.hook_v
# blocks.4.attn.hook_k
# blocks.4.attn.hook_q
# blocks.4.ln1.hook_normalized
# blocks.4.ln1.hook_scale
# blocks.4.hook_v_input
# blocks.4.hook_k_input
# blocks.4.hook_q_input
# blocks.4.hook_resid_pre
# blocks.3.hook_resid_post
# blocks.3.hook_mlp_out
# blocks.3.mlp.hook_post
# blocks.3.mlp.hook_pre
# blocks.3.ln2.hook_normalized
# blocks.3.ln2.hook_scale
# blocks.3.hook_mlp_in
# blocks.3.hook_resid_mid
# blocks.3.hook_attn_out
# blocks.3.attn.hook_result
# blocks.3.attn.hook_z
# blocks.3.attn.hook_pattern
# blocks.3.attn.hook_attn_scores
# blocks.3.attn.hook_v
# blocks.3.attn.hook_k
# blocks.3.attn.hook_q
# blocks.3.ln1.hook_normalized
# blocks.3.ln1.hook_scale
# blocks.3.hook_v_input
# blocks.3.hook_k_input
# blocks.3.hook_q_input
# blocks.3.hook_resid_pre
# blocks.2.hook_resid_post
# blocks.2.hook_mlp_out
# blocks.2.mlp.hook_post
# blocks.2.mlp.hook_pre
# blocks.2.ln2.hook_normalized
# blocks.2.ln2.hook_scale
# blocks.2.hook_mlp_in
# blocks.2.hook_resid_mid
# blocks.2.hook_attn_out
# blocks.2.attn.hook_result
# blocks.2.attn.hook_z
# blocks.2.attn.hook_pattern
# blocks.2.attn.hook_attn_scores
# blocks.2.attn.hook_v
# blocks.2.attn.hook_k
# blocks.2.attn.hook_q
# blocks.2.ln1.hook_normalized
# blocks.2.ln1.hook_scale
# blocks.2.hook_v_input
# blocks.2.hook_k_input
# blocks.2.hook_q_input
# blocks.2.hook_resid_pre
# blocks.1.hook_resid_post
# blocks.1.hook_mlp_out
# blocks.1.mlp.hook_post
# blocks.1.mlp.hook_pre
# blocks.1.ln2.hook_normalized
# blocks.1.ln2.hook_scale
# blocks.1.hook_mlp_in
# blocks.1.hook_resid_mid
# blocks.1.hook_attn_out
# blocks.1.attn.hook_result
# blocks.1.attn.hook_z
# blocks.1.attn.hook_pattern
# blocks.1.attn.hook_attn_scores
# blocks.1.attn.hook_v
# blocks.1.attn.hook_k
# blocks.1.attn.hook_q
# blocks.1.ln1.hook_normalized
# blocks.1.ln1.hook_scale
# blocks.1.hook_v_input
# blocks.1.hook_k_input
# blocks.1.hook_q_input
# blocks.1.hook_resid_pre
# blocks.0.hook_resid_post
# blocks.0.hook_mlp_out
# blocks.0.mlp.hook_post
# blocks.0.mlp.hook_pre
# blocks.0.ln2.hook_normalized
# blocks.0.ln2.hook_scale
# blocks.0.hook_mlp_in
# blocks.0.hook_resid_mid
# blocks.0.hook_attn_out
# blocks.0.attn.hook_result
# blocks.0.attn.hook_z
# blocks.0.attn.hook_pattern
# blocks.0.attn.hook_attn_scores
# blocks.0.attn.hook_v
# blocks.0.attn.hook_k
# blocks.0.attn.hook_q
# blocks.0.ln1.hook_normalized
# blocks.0.ln1.hook_scale
# blocks.0.hook_v_input
# blocks.0.hook_k_input
# blocks.0.hook_q_input
# blocks.0.hook_resid_pre
# hook_pos_embed
# hook_embed
# self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:])
# Adding sender hooks...
# Done corrupting things
# Adding sender hooks...
# No edge 32923

# %% [markdown]
# #### Step 3: Patch Model Activations to Isolate the relevant Subgraph

# %%
import gc
import time
from dataclasses import dataclass, asdict
from IPython import get_ipython
from IPython.display import Image, display

ipython = get_ipython()

from acdc.acdc_graphics import show

max_num_epochs = 100000
single_step = False
for i in range(max_num_epochs):
    exp.step(testing=False)

    show(
        exp.corr,
        f"ims/img_new_{i+1}.png",
        show_full_index=args.use_pos_embed,
    )

    if ipython is not None:
        # so long as we're not running this as a script, show the image!
        display(Image(f"ims/img_new_{i+1}.png"))

    print(i, "-" * 50)
    print(exp.count_no_edges())

    if i == 0:
        exp.save_edges("edges.pkl")

    if exp.current_node is None or single_step:
        break

exp.save_edges("another_final_edges.pkl")
# Out:
# No edge 32923
# New metric: -0.8664211630821228
#
# Node: cur_parent=TLACDCInterpNode(blocks.11.hook_mlp_out, [:]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.11.hook_mlp_out [:] is -0.9255590438842773 (and current metric -0.8664211630821228)
# Result is -0.05913788080215454...so removing connection
# No edge 32922
#
# Node: cur_parent=TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 0]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.11.attn.hook_result [:, :, 0] is -0.9160527586936951 (and current metric -0.9255590438842773)
# Result is 0.009506285190582275...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 1]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.11.attn.hook_result [:, :, 1] is -0.9182395935058594 (and current metric -0.9160527586936951)
# Result is -0.0021868348121643066...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 2]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.11.attn.hook_result [:, :, 2] is -0.9219902157783508 (and current metric -0.9182395935058594)
# Result is -0.003750622272491455...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 3]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.11.attn.hook_result [:, :, 3] is -0.9239363074302673 (and current metric -0.9219902157783508)
# Result is -0.001946091651916504...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.11.attn.hook_result, [:, :, 4]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.11.attn.hook_result [:, :,
so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 2]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 2] is -0.00042073457734659314 (and current metric -0.0004826037329621613)
# Result is 6.186915561556816e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 3]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 3] is -0.0004004266520496458 (and current metric -0.00042073457734659314)
# Result is 2.030792529694736e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 4]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 4] is -0.0004193347122054547 (and current metric -0.0004004266520496458)
# Result is -1.8908060155808926e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 5]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 5] is -0.0003226941917091608 (and current metric -0.0004193347122054547)
# Result is 9.66405204962939e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 6]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 6] is -0.00038354992284439504 (and current metric -0.0003226941917091608)
# Result is -6.085573113523424e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 7]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 7] is -0.0004007006937172264 (and current metric -0.00038354992284439504)
# Result is -1.7150770872831345e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 8]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 8] is -0.00039178106817416847 (and current metric -0.0004007006937172264)
# Result is 8.919625543057919e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 9]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 9] is -0.00023209709615912288 (and current metric -0.00039178106817416847)
# Result is 0.00015968397201504558...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 10]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 10] is -0.00019324172171764076 (and current metric -0.00023209709615912288)
# Result is 3.885537444148213e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.6.attn.hook_result, [:, :, 11]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.6.attn.hook_result [:, :, 11] is -0.0002167873171856627 (and current metric -0.00019324172171764076)
# Result is -2.354559546802193e-05...so removing connection
# No edge 32845
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.hook_mlp_out, [:]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.hook_mlp_out [:] is -0.0001705219765426591 (and current metric -0.0002167873171856627)
# Result is 4.626534064300358e-05...so removing connection
# No edge 32844
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 0]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 0] is -0.00014472597104031593 (and current metric -0.0001705219765426591)
# Result is 2.5796005502343178e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 1]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 1] is -0.0001220300910063088 (and current metric -0.00014472597104031593)
# Result is 2.2695880034007132e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 2]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 2] is -0.00013413447595667094 (and current metric -0.0001220300910063088)
# Result is -1.2104384950362146e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 3]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 3] is -0.00013943357043899596 (and current metric -0.00013413447595667094)
# Result is -5.2990944823250175e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 4]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 4] is -0.0001423259382136166 (and current metric -0.00013943357043899596)
# Result is -2.892367774620652e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 5]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 5] is -9.294354094890878e-05 (and current metric -0.0001423259382136166)
# Result is 4.9382397264707834e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 6]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 6] is -9.046497143572196e-05 (and current metric -9.294354094890878e-05)
# Result is 2.4785695131868124e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 7]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 7] is -8.683127089170739e-05 (and current metric -9.046497143572196e-05)
# Result is 3.633700544014573e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 8]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 8] is -7.278064003912732e-05 (and current metric -8.683127089170739e-05)
# Result is 1.405063085258007e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 9]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 9] is -9.508243965683505e-05 (and current metric -7.278064003912732e-05)
# Result is -2.230179961770773e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 10]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 10] is -8.779382187640294e-05 (and current metric -9.508243965683505e-05)
# Result is 7.288617780432105e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.5.attn.hook_result, [:, :, 11]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.5.attn.hook_result [:, :, 11] is -8.768133557168767e-05 (and current metric -8.779382187640294e-05)
# Result is 1.1248630471527576e-07...so removing connection
# No edge 32832
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.hook_mlp_out, [:]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.hook_mlp_out [:] is -6.744448182871565e-05 (and current metric -8.768133557168767e-05)
# Result is 2.0236853742972016e-05...so removing connection
# No edge 32831
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 0]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 0] is -6.822661816840991e-05 (and current metric -6.744448182871565e-05)
# Result is -7.821363396942616e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 1]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 1] is -6.593803846044466e-05 (and current metric -6.822661816840991e-05)
# Result is 2.2885797079652548e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 2]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 2] is -6.990827387198806e-05 (and current metric -6.593803846044466e-05)
# Result is -3.970235411543399e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 3]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 3] is -7.210780313471332e-05 (and current metric -6.990827387198806e-05)
# Result is -2.199529262725264e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 4]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 4] is -6.968760135350749e-05 (and current metric -7.210780313471332e-05)
# Result is 2.420201781205833e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 5]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 5] is -7.925422687549144e-05 (and current metric -6.968760135350749e-05)
# Result is -9.566625521983951e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 6]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 6] is -7.677756366319954e-05 (and current metric -7.925422687549144e-05)
# Result is 2.4766632122918963e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 7]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 7] is -7.282320439117029e-05 (and current metric -7.677756366319954e-05)
# Result is 3.954359272029251e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 8]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 8] is -5.9855701692868024e-05 (and current metric -7.282320439117029e-05)
# Result is 1.2967502698302269e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 9]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 9] is -5.64691836189013e-05 (and current metric -5.9855701692868024e-05)
# Result is 3.3865180739667267e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 10]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 10] is -5.5550488468725234e-05 (and current metric -5.64691836189013e-05)
# Result is 9.186951501760632e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.4.attn.hook_result, [:, :, 11]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.4.attn.hook_result [:, :, 11] is -5.515768498298712e-05 (and current metric -5.5550488468725234e-05)
# Result is 3.928034857381135e-07...so removing connection
# No edge 32819
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.hook_mlp_out, [:]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.hook_mlp_out [:] is -5.012729889131151e-05 (and current metric -5.515768498298712e-05)
# Result is 5.030386091675609e-06...so removing connection
# No edge 32818
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 0]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 0] is -5.1475515647325665e-05 (and current metric -5.012729889131151e-05)
# Result is -1.3482167560141534e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 1]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 1] is -5.34529062861111e-05 (and current metric -5.1475515647325665e-05)
# Result is -1.9773906387854367e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 2]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 2] is -5.4340427595889196e-05 (and current metric -5.34529062861111e-05)
# Result is -8.875213097780943e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 3]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 3] is -5.304974183673039e-05 (and current metric -5.4340427595889196e-05)
# Result is 1.290685759158805e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 4]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 4] is -5.485151268658228e-05 (and current metric -5.304974183673039e-05)
# Result is -1.8017708498518914e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 5]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 5] is -5.285284714773297e-05 (and current metric -5.485151268658228e-05)
# Result is 1.998665538849309e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 6]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 6] is -4.973925024387427e-05 (and current metric -5.285284714773297e-05)
# Result is 3.1135969038587064e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 7]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 7] is -5.4083382565295324e-05 (and current metric -4.973925024387427e-05)
# Result is -4.344132321421057e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 8]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 8] is -5.507586683961563e-05 (and current metric -5.4083382565295324e-05)
# Result is -9.924842743203044e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 9]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 9] is -5.5951812100829557e-05 (and current metric -5.507586683961563e-05)
# Result is -8.759452612139285e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 10]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 10] is -6.834183295723051e-05 (and current metric -5.5951812100829557e-05)
# Result is -1.2390020856400952e-05...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.3.attn.hook_result, [:, :, 11]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.3.attn.hook_result [:, :, 11] is -6.909001240273938e-05 (and current metric -6.834183295723051e-05)
# Result is -7.481794455088675e-07...so removing connection
# No edge 32806
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.hook_mlp_out, [:]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.hook_mlp_out [:] is -6.356502854032442e-05 (and current metric -6.909001240273938e-05)
# Result is 5.524983862414956e-06...so removing connection
# No edge 32805
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 0]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 0] is -6.436649709939957e-05 (and current metric -6.356502854032442e-05)
# Result is -8.014685590751469e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 1]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 1] is -5.969042467768304e-05 (and current metric -6.436649709939957e-05)
# Result is 4.676072421716526e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 2]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 2] is -5.567559855990112e-05 (and current metric -5.969042467768304e-05)
# Result is 4.014826117781922e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 3]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 3] is -5.244365820544772e-05 (and current metric -5.567559855990112e-05)
# Result is 3.2319403544533998e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 4]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 4] is -4.8937712563201785e-05 (and current metric -5.244365820544772e-05)
# Result is 3.5059456422459334e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 5]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 5] is -5.1974562666146085e-05 (and current metric -4.8937712563201785e-05)
# Result is -3.0368501029442996e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 6]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 6] is -4.5418779336614534e-05 (and current metric -5.1974562666146085e-05)
# Result is 6.55578332953155e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 7]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 7] is -4.774436820298433e-05 (and current metric -4.5418779336614534e-05)
# Result is -2.3255888663697988e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 8]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 8] is -4.97334185638465e-05 (and current metric -4.774436820298433e-05)
# Result is -1.9890503608621657e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 9]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 9] is -5.237052027950995e-05 (and current metric -4.97334185638465e-05)
# Result is -2.637101715663448e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 10]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 10] is -5.25629693584051e-05 (and current metric -5.237052027950995e-05)
# Result is -1.9244907889515162e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.2.attn.hook_result, [:, :, 11]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.2.attn.hook_result [:, :, 11] is -5.5048814829206094e-05 (and current metric -5.25629693584051e-05)
# Result is -2.485845470800996e-06...so removing connection
# No edge 32793
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.hook_mlp_out, [:]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.hook_mlp_out [:] is -4.679755147662945e-05 (and current metric -5.5048814829206094e-05)
# Result is 8.251263352576643e-06...so removing connection
# No edge 32792
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.attn.hook_result, [:, :, 0]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.attn.hook_result [:, :, 0] is -4.628377428161912e-05 (and current metric -4.679755147662945e-05)
# Result is 5.137771950103343e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.attn.hook_result, [:, :, 1]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.attn.hook_result [:, :, 1] is -4.544775583781302e-05 (and current metric -4.628377428161912e-05)
# Result is 8.360184438060969e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.attn.hook_result, [:, :, 2]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.attn.hook_result [:, :, 2] is -4.571647150442004e-05 (and current metric -4.544775583781302e-05)
# Result is -2.687156666070223e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.attn.hook_result, [:, :, 3]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.attn.hook_result [:, :, 3] is -4.500482464209199e-05 (and current metric -4.571647150442004e-05)
# Result is 7.116468623280525e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.attn.hook_result, [:, :, 4]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.attn.hook_result [:, :, 4] is -4.385390639072284e-05 (and current metric -4.500482464209199e-05)
# Result is 1.1509182513691485e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.attn.hook_result, [:, :, 5]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.attn.hook_result [:, :, 5] is -4.077897756360471e-05 (and current metric -4.385390639072284e-05)
# Result is 3.0749288271181285e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.attn.hook_result, [:, :, 6]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.attn.hook_result [:, :, 6] is -3.914066110155545e-05 (and current metric -4.077897756360471e-05)
# Result is 1.6383164620492607e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.attn.hook_result, [:, :, 7]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.attn.hook_result [:, :, 7] is -3.725162969203666e-05 (and current metric -3.914066110155545e-05)
# Result is 1.8890314095187932e-06...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.1.attn.hook_result, [:, :, 8]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.1.attn.hook_result [:, :, 8] is -3.698185537359677e-05 (and current metric -3.725162969203666e-05)
# Result is 2.69774318439886e-07...so removing connection
#
# ...
# Result is 2.402703103143722e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 10]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.0.attn.hook_result [:, :, 10] is -1.0484094673302025e-05 (and current metric -1.084624818759039e-05)
# Result is 3.6215351428836584e-07...so removing connection
#
# Node: cur_parent=TLACDCInterpNode(blocks.0.attn.hook_result, [:, :, 11]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.0.attn.hook_result [:, :, 11] is -9.388621947437059e-06 (and current metric -1.0484094673302025e-05)
# Result is 1.0954727258649655e-06...so removing connection
# No edge 32767
#
# Node: cur_parent=TLACDCInterpNode(blocks.0.hook_resid_pre, [:]) (self.current_node=TLACDCInterpNode(blocks.11.hook_resid_post, [:]))
#
# Metric after removing connection to blocks.0.hook_resid_pre [:] is -9.509750270808581e-06 (and current metric -9.388621947437059e-06)
# Result is -1.2112832337152213e-07...so removing connection
# No edge 32766
# We moved to  blocks.11.hook_mlp_out[:]
# No edge 32766
# No edge 32766
# But it's bad
# We moved to  blocks.11.hook_mlp_in[:]
# No edge 32766
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 11]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 10]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 9]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 8]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 7]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 6]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 5]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 4]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 3]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 2]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 1]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_result[:, :, 0]
# No edge 32610
# No edge 32610
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 11]
# No edge 32610
# No edge 32609
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 10]
# No edge 32609
# No edge 32608
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 9]
# No edge 32608
# No edge 32607
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 8]
# No edge 32607
# No edge 32606
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 7]
# No edge 32606
# No edge 32605
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 6]
# No edge 32605
# No edge 32604
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 5]
# No edge 32604
# No edge 32603
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 4]
# No edge 32603
# No edge 32602
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 3]
# No edge 32602
# No edge 32601
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 2]
# No edge 32601
# No edge 32600
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 1]
# No edge 32600
# No edge 32599
# But it's bad
# We moved to  blocks.11.attn.hook_v[:, :, 0]
# No edge 32599
# No edge 32598
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 11]
# No edge 32598
# No edge 32597
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 10]
# No edge 32597
# No edge 32596
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 9]
# No edge 32596
# No edge 32595
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 8]
# No edge 32595
# No edge 32594
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 7]
# No edge 32594
# No edge 32593
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 6]
# No edge 32593
# No edge 32592
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 5]
# No edge 32592
# No edge 32591
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 4]
# No edge 32591
# No edge 32590
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 3]
# No edge 32590
# No edge 32589
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 2]
# No edge 32589
# No edge 32588
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 1]
# No edge 32588
# No edge 32587
# But it's bad
# We moved to  blocks.11.attn.hook_k[:, :, 0]
# No edge 32587
# No edge 32586
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 11]
# No edge 32586
# No edge 32585
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 10]
# No edge 32585
# No edge 32584
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 9]
# No edge 32584
# No edge 32583
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 8]
# No edge 32583
# No edge 32582
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 7]
# No edge 32582
# No edge 32581
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 6]
# No edge 32581
# No edge 32580
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 5]
# No edge 32580
# No edge 32579
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 4]
# No edge 32579
# No edge 32578
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 3]
# No edge 32578
# No edge 32577
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 2]
# No edge 32577
# No edge 32576
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 1]
# No edge 32576
# No edge 32575
# But it's bad
# We moved to  blocks.11.attn.hook_q[:, :, 0]
# No edge 32575
# No edge 32574
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 11]
# No edge 32574
# No edge 32430
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 10]
# No edge 32430
# No edge 32286
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 9]
# No edge 32286
# No edge 32142
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 8]
# No edge 32142
# No edge 31998
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 7]
# No edge 31998
# No edge 31854
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 6]
# No edge 31854
# No edge 31710
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 5]
# No edge 31710
# No edge 31566
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 4]
# No edge 31566
# No edge 31422
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 3]
# No edge 31422
# No edge 31278
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 2]
# No edge 31278
# No edge 31134
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 1]
# No edge 31134
# No edge 30990
# But it's bad
# We moved to  blocks.11.hook_v_input[:, :, 0]
# No edge 30990
# No edge 30846
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 11]
# No edge 30846
# No edge 30702
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 10]
# No edge 30702
# No edge 30558
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 9]
# No edge 30558
# No edge 30414
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 8]
# No edge 30414
# No edge 30270
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 7]
# No edge 30270
# No edge 30126
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 6]
# No edge 30126
# No edge 29982
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 5]
# No edge 29982
# No edge 29838
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 4]
# No edge 29838
# No edge 29694
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 3]
# No edge 29694
# No edge 29550
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 2]
# No edge 29550
# No edge 29406
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 1]
# No edge 29406
# No edge 29262
# But it's bad
# We moved to  blocks.11.hook_k_input[:, :, 0]
# No edge 29262
# No edge 29118
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 11]
# No edge 29118
# No edge 28974
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 10]
# No edge 28974
# No edge 28830
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 9]
# No edge 28830
# No edge 28686
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 8]
# No edge 28686
# No edge 28542
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 7]
# No edge 28542
# No edge 28398
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 6]
# No edge 28398
# No edge 28254
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 5]
# No edge 28254
# No edge 28110
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 4]
# No edge 28110
# No edge 27966
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 3]
# No edge 27966
# No edge 27822
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 2]
# No edge 27822
# No edge 27678
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 1]
# No edge 27678
# No edge 27534
# But it's bad
# We moved to  blocks.11.hook_q_input[:, :, 0]
# No edge 27534
# No edge 27390
# But it's bad
# We moved to  blocks.10.hook_mlp_out[:]
# No edge 27390
# No edge 27390
# But it's bad
# We moved to  blocks.10.hook_mlp_in[:]
# No edge 27390
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 11]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 10]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 9]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 8]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 7]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 6]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 5]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 4]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 3]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 2]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 1]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_result[:, :, 0]
# No edge 27247
# No edge 27247
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 11]
# No edge 27247
# No edge 27246
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 10]
# No edge 27246
# No edge 27245
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 9]
# No edge 27245
# No edge 27244
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 8]
# No edge 27244
# No edge 27243
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 7]
# No edge 27243
# No edge 27242
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 6]
# No edge 27242
# No edge 27241
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 5]
# No edge 27241
# No edge 27240
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 4]
# No edge 27240
# No edge 27239
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 3]
# No edge 27239
# No edge 27238
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 2]
# No edge 27238
# No edge 27237
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 1]
# No edge 27237
# No edge 27236
# But it's bad
# We moved to  blocks.10.attn.hook_v[:, :, 0]
# No edge 27236
# No edge 27235
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 11]
# No edge 27235
# No edge 27234
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 10]
# No edge 27234
# No edge 27233
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 9]
# No edge 27233
# No edge 27232
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 8]
# No edge 27232
# No edge 27231
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 7]
# No edge 27231
# No edge 27230
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 6]
# No edge 27230
# No edge 27229
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 5]
# No edge 27229
# No edge 27228
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 4]
# No edge 27228
# No edge 27227
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 3]
# No edge 27227
# No edge 27226
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 2]
# No edge 27226
# No edge 27225
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 1]
# No edge 27225
# No edge 27224
# But it's bad
# We moved to  blocks.10.attn.hook_k[:, :, 0]
# No edge 27224
# No edge 27223
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 11]
# No edge 27223
# No edge 27222
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 10]
# No edge 27222
# No edge 27221
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 9]
# No edge 27221
# No edge 27220
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 8]
# No edge 27220
# No edge 27219
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 7]
# No edge 27219
# No edge 27218
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 6]
# No edge 27218
# No edge 27217
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 5]
# No edge 27217
# No edge 27216
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 4]
# No edge 27216
# No edge 27215
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 3]
# No edge 27215
# No edge 27214
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 2]
# No edge 27214
# No edge 27213
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 1]
# No edge 27213
# No edge 27212
# But it's bad
# We moved to  blocks.10.attn.hook_q[:, :, 0]
# No edge 27212
# No edge 27211
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 11]
# No edge 27211
# No edge 27080
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 10]
# No edge 27080
# No edge 26949
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 9]
# No edge 26949
# No edge 26818
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 8]
# No edge 26818
# No edge 26687
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 7]
# No edge 26687
# No edge 26556
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 6]
# No edge 26556
# No edge 26425
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 5]
# No edge 26425
# No edge 26294
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 4]
# No edge 26294
# No edge 26163
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 3]
# No edge 26163
# No edge 26032
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 2]
# No edge 26032
# No edge 25901
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 1]
# No edge 25901
# No edge 25770
# But it's bad
# We moved to  blocks.10.hook_v_input[:, :, 0]
# No edge 25770
# No edge 25639
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 11]
# No edge 25639
# No edge 25508
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 10]
# No edge 25508
# No edge 25377
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 9]
# No edge 25377
# No edge 25246
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 8]
# No edge 25246
# No edge 25115
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 7]
# No edge 25115
# No edge 24984
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 6]
# No edge 24984
# No edge 24853
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 5]
# No edge 24853
# No edge 24722
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 4]
# No edge 24722
# No edge 24591
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 3]
# No edge 24591
# No edge 24460
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 2]
# No edge 24460
# No edge 24329
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 1]
# No edge 24329
# No edge 24198
# But it's bad
# We moved to  blocks.10.hook_k_input[:, :, 0]
# No edge 24198
# No edge 24067
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 11]
# No edge 24067
# No edge 23936
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 10]
# No edge 23936
# No edge 23805
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 9]
# No edge 23805
# No edge 23674
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 8]
# No edge 23674
# No edge 23543
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 7]
# No edge 23543
# No edge 23412
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 6]
# No edge 23412
# No edge 23281
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 5]
# No edge 23281
# No edge 23150
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 4]
# No edge 23150
# No edge 23019
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 3]
# No edge 23019
# No edge 22888
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 2]
# No edge 22888
# No edge 22757
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 1]
# No edge 22757
# No edge 22626
# But it's bad
# We moved to  blocks.10.hook_q_input[:, :, 0]
# No edge 22626
# No edge 22495
# But it's bad
# We moved to  blocks.9.hook_mlp_out[:]
