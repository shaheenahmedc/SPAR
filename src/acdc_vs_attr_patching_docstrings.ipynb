# %% [markdown]
# ## Setup

# %%
import numpy
import plotly
import os
import torch
import importlib
# some GPU setup
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"  # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# # Overview

# %% [markdown]
# In this notebook, I'm going to try and replicate some results from the ACDC paper, and the ACDC++
# repo. From ACDC:
# 1. ROC docstrings curve ![image.png](attachment:image.png)
# 2. Circuit recovered: ![image-2.png](attachment:image-2.png)

# %% [markdown]
# From ACDC++:
# 1. [ROC Curve](https://github.com/Aaquib111/acdcpp/blob/e627a659539e52633a2af40939373b6ebb44a12f/docstring_task/Results%20Analysis.ipynb)![image.png](attachment:image.png)

# %% [markdown]
# # ACDC

# %% [markdown]
# ## Select Model

# %%
from transformer_lens import HookedTransformer

# This model used in docstrings post
attn_only_4l = HookedTransformer.from_pretrained("attn-only-4l")

# %% [markdown]
# ## Select Dataset

# %% [markdown]
# Data = `validation_data` and `validation_patch_data` here:
# https://github.com/ArthurConmy/Automatic-Circuit-Discovery/blob/7787aa7753092fbe6fb9933d8f12d0ff3a546bc7/acdc/docstring/utils.py
# Used in main.py here:
# https://github.com/ArthurConmy/Automatic-Circuit-Discovery/blob/7787aa7753092fbe6fb9933d8f12d0ff3a546bc7/acdc/main.py
# Elif statement for docstrings tasks, two datasets grabbed from docstrings utils

# %%
from Automatic_Circuit_Discovery_Copy.acdc.docstring.utils import get_all_docstring_things
